# %%
##讀取套件

import numpy as np
import matplotlib.pyplot as plt

# Import some useful packages
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, IntSlider, FloatSlider

import tensorflow as tf
import tensorflow.keras.backend as K

# Layers for FNN
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Lambda, concatenate
from tensorflow.keras.layers import Dense

# Optimizers for training
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import metrics

# Losses for training
from tensorflow.keras import losses

# For data preprocessing
from tensorflow.keras import datasets
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train0), (x_test, y_test0) = datasets.fashion_mnist.load_data()

# %%
# Reshape sizeL:將 x 改成784維度
x_train = x_train.reshape(-1, 28*28)
x_test = x_test.reshape(-1, 28*28)

# Normalize the range of featurs
x_train = x_train / x_train.max()
x_test = x_test / x_test.max()

# One-hot encoding:將y轉換成類別資料
y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)

# %% [markdown]
# 將encoder與decoder各加一層，並更改神經元個數試試。

# %%
x = Input(shape=(784,))

enc_1 = Dense(128, activation='sigmoid')
enc_2 = Dense(64, activation='sigmoid')
enc_3 = Dense(2, activation='sigmoid')

z = enc_3(enc_2(enc_1(x)))

dec_3 = Dense(64, activation='sigmoid')
dec_2 = Dense(128, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')

x_hat = dec_1(dec_2(dec_3(z)))

# %%
autoencoder = Model(x, x_hat)
autoencoder.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 130
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_41 (Dense)             (None, 784)               101136
# =================================================================
# Total params: 218,514
# Trainable params: 218,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(loss='mse',
                    optimizer=Adam(5e-3),
                    metrics=['mae']
                    )

# %%
autoencoder.fit(x_train,x_train,
                batch_size=128,
                epochs=150,
                validation_data=(x_test,x_test)
                )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/150
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.0684 - mean_absolute_error: 0.1936 - val_loss: 0.0582 - val_mean_absolute_error: 0.1705
# Epoch 2/150
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0439 - mean_absolute_error: 0.1390 - val_loss: 0.0366 - val_mean_absolute_error: 0.1215
# Epoch 3/150
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0350 - mean_absolute_error: 0.1150 - val_loss: 0.0334 - val_mean_absolute_error: 0.1115
# Epoch 4/150
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0329 - mean_absolute_error: 0.1099 - val_loss: 0.0319 - val_mean_absolute_error: 0.1075
# Epoch 5/150
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0313 - mean_absolute_error: 0.1056 - val_loss: 0.0308 - val_mean_absolute_error: 0.1045
# Epoch 6/150
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0301 - mean_absolute_error: 0.1024 - val_loss: 0.0296 - val_mean_absolute_error: 0.1020
# Epoch 7/150
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0294 - mean_absolute_error: 0.1003 - val_loss: 0.0293 - val_mean_absolute_error: 0.0997
# Epoch 8/150
# 60000/60000 [==============================] - 4s 58us/sample - loss: 0.0289 - mean_absolute_error: 0.0988 - val_loss: 0.0288 - val_mean_absolute_error: 0.0985
# Epoch 9/150
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0285 - mean_absolute_error: 0.0976 - val_loss: 0.0295 - val_mean_absolute_error: 0.0988
# Epoch 10/150
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0283 - mean_absolute_error: 0.0970 - val_loss: 0.0282 - val_mean_absolute_error: 0.0965
# Epoch 11/150
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0279 - mean_absolute_error: 0.0959 - val_loss: 0.0279 - val_mean_absolute_error: 0.0957
# Epoch 12/150
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.0277 - mean_absolute_error: 0.0954 - val_loss: 0.0278 - val_mean_absolute_error: 0.0958
# Epoch 13/150
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.0274 - mean_absolute_error: 0.0948 - val_loss: 0.0272 - val_mean_absolute_error: 0.0941
# Epoch 14/150
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0271 - mean_absolute_error: 0.0940 - val_loss: 0.0274 - val_mean_absolute_error: 0.0952
# Epoch 15/150
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.0270 - mean_absolute_error: 0.0936 - val_loss: 0.0272 - val_mean_absolute_error: 0.0942
# Epoch 16/150
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0269 - mean_absolute_error: 0.0933 - val_loss: 0.0268 - val_mean_absolute_error: 0.0931
# Epoch 17/150
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0267 - mean_absolute_error: 0.0928 - val_loss: 0.0274 - val_mean_absolute_error: 0.0953
# Epoch 18/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0267 - mean_absolute_error: 0.0929 - val_loss: 0.0265 - val_mean_absolute_error: 0.0922
# Epoch 19/150
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0264 - mean_absolute_error: 0.0922 - val_loss: 0.0263 - val_mean_absolute_error: 0.0920
# Epoch 20/150
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0263 - mean_absolute_error: 0.0919 - val_loss: 0.0267 - val_mean_absolute_error: 0.0926
# Epoch 21/150
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0263 - mean_absolute_error: 0.0918 - val_loss: 0.0269 - val_mean_absolute_error: 0.0939
# Epoch 22/150
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0262 - mean_absolute_error: 0.0915 - val_loss: 0.0266 - val_mean_absolute_error: 0.0921
# Epoch 23/150
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.0261 - mean_absolute_error: 0.0914 - val_loss: 0.0262 - val_mean_absolute_error: 0.0918
# Epoch 24/150
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0261 - mean_absolute_error: 0.0913 - val_loss: 0.0261 - val_mean_absolute_error: 0.0908
# Epoch 25/150
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.0261 - mean_absolute_error: 0.0912 - val_loss: 0.0263 - val_mean_absolute_error: 0.0918
# Epoch 26/150
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.0261 - mean_absolute_error: 0.0912 - val_loss: 0.0261 - val_mean_absolute_error: 0.0916
# Epoch 27/150
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.0257 - mean_absolute_error: 0.0905 - val_loss: 0.0257 - val_mean_absolute_error: 0.0909
# Epoch 28/150
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0259 - mean_absolute_error: 0.0908 - val_loss: 0.0260 - val_mean_absolute_error: 0.0911
# Epoch 29/150
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.0257 - mean_absolute_error: 0.0904 - val_loss: 0.0261 - val_mean_absolute_error: 0.0911
# Epoch 30/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0256 - mean_absolute_error: 0.0902 - val_loss: 0.0256 - val_mean_absolute_error: 0.0901
# Epoch 31/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0254 - mean_absolute_error: 0.0897 - val_loss: 0.0257 - val_mean_absolute_error: 0.0906
# Epoch 32/150
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0254 - mean_absolute_error: 0.0895 - val_loss: 0.0255 - val_mean_absolute_error: 0.0899
# Epoch 33/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0252 - mean_absolute_error: 0.0893 - val_loss: 0.0254 - val_mean_absolute_error: 0.0894
# Epoch 34/150
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.0253 - mean_absolute_error: 0.0894 - val_loss: 0.0254 - val_mean_absolute_error: 0.0901
# Epoch 35/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0252 - mean_absolute_error: 0.0890 - val_loss: 0.0253 - val_mean_absolute_error: 0.0893
# Epoch 36/150
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.0252 - mean_absolute_error: 0.0890 - val_loss: 0.0254 - val_mean_absolute_error: 0.0899
# Epoch 37/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0251 - mean_absolute_error: 0.0888 - val_loss: 0.0255 - val_mean_absolute_error: 0.0895
# Epoch 38/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0250 - mean_absolute_error: 0.0886 - val_loss: 0.0251 - val_mean_absolute_error: 0.0884s: 0.0250 - mean_ab
# Epoch 39/150
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0251 - mean_absolute_error: 0.0887 - val_loss: 0.0254 - val_mean_absolute_error: 0.0896
# Epoch 40/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0249 - mean_absolute_error: 0.0883 - val_loss: 0.0253 - val_mean_absolute_error: 0.0893
# Epoch 41/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0251 - mean_absolute_error: 0.0886 - val_loss: 0.0254 - val_mean_absolute_error: 0.0898oss: 0.0251 - mean_absolute_error: 0
# Epoch 42/150
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0249 - mean_absolute_error: 0.0882 - val_loss: 0.0251 - val_mean_absolute_error: 0.0888
# Epoch 43/150
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.0249 - mean_absolute_error: 0.0882 - val_loss: 0.0253 - val_mean_absolute_error: 0.0892
# Epoch 44/150
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.0248 - mean_absolute_error: 0.0880 - val_loss: 0.0251 - val_mean_absolute_error: 0.0885
# Epoch 45/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0247 - mean_absolute_error: 0.0878 - val_loss: 0.0248 - val_mean_absolute_error: 0.0882
# Epoch 46/150
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0246 - mean_absolute_error: 0.0877 - val_loss: 0.0249 - val_mean_absolute_error: 0.0880
# Epoch 47/150
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0246 - mean_absolute_error: 0.0877 - val_loss: 0.0250 - val_mean_absolute_error: 0.0886
# Epoch 48/150
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.0246 - mean_absolute_error: 0.0876 - val_loss: 0.0251 - val_mean_absolute_error: 0.0884
# Epoch 49/150
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0247 - mean_absolute_error: 0.0878 - val_loss: 0.0252 - val_mean_absolute_error: 0.0888
# Epoch 50/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0246 - mean_absolute_error: 0.0876 - val_loss: 0.0251 - val_mean_absolute_error: 0.0893
# Epoch 51/150
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0246 - mean_absolute_error: 0.0876 - val_loss: 0.0249 - val_mean_absolute_error: 0.0881
# Epoch 52/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0244 - mean_absolute_error: 0.0871 - val_loss: 0.0247 - val_mean_absolute_error: 0.0877
# Epoch 53/150
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0245 - mean_absolute_error: 0.0874 - val_loss: 0.0248 - val_mean_absolute_error: 0.0878
# Epoch 54/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0245 - mean_absolute_error: 0.0873 - val_loss: 0.0248 - val_mean_absolute_error: 0.0877
# Epoch 55/150
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0246 - mean_absolute_error: 0.0874 - val_loss: 0.0249 - val_mean_absolute_error: 0.0884
# Epoch 56/150
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.0245 - mean_absolute_error: 0.0873 - val_loss: 0.0247 - val_mean_absolute_error: 0.0875
# Epoch 57/150
# 60000/60000 [==============================] - 7s 108us/sample - loss: 0.0245 - mean_absolute_error: 0.0873 - val_loss: 0.0247 - val_mean_absolute_error: 0.0878
# Epoch 58/150
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0244 - mean_absolute_error: 0.0871 - val_loss: 0.0253 - val_mean_absolute_error: 0.0900
# Epoch 59/150
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0243 - mean_absolute_error: 0.0870 - val_loss: 0.0247 - val_mean_absolute_error: 0.0880
# Epoch 60/150
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0244 - mean_absolute_error: 0.0871 - val_loss: 0.0248 - val_mean_absolute_error: 0.0878
# Epoch 61/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0244 - mean_absolute_error: 0.0869 - val_loss: 0.0248 - val_mean_absolute_error: 0.0879
# Epoch 62/150
# 60000/60000 [==============================] - 7s 113us/sample - loss: 0.0243 - mean_absolute_error: 0.0868 - val_loss: 0.0247 - val_mean_absolute_error: 0.0876
# Epoch 63/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0243 - mean_absolute_error: 0.0868 - val_loss: 0.0249 - val_mean_absolute_error: 0.0874
# Epoch 64/150
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0242 - mean_absolute_error: 0.0866 - val_loss: 0.0247 - val_mean_absolute_error: 0.0875
# Epoch 65/150
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0242 - mean_absolute_error: 0.0866 - val_loss: 0.0248 - val_mean_absolute_error: 0.0880
# Epoch 66/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0242 - mean_absolute_error: 0.0865 - val_loss: 0.0246 - val_mean_absolute_error: 0.0870
# Epoch 67/150
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0242 - mean_absolute_error: 0.0865 - val_loss: 0.0247 - val_mean_absolute_error: 0.0871
# Epoch 68/150
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0243 - mean_absolute_error: 0.0867 - val_loss: 0.0247 - val_mean_absolute_error: 0.0874
# Epoch 69/150
# 60000/60000 [==============================] - 7s 112us/sample - loss: 0.0242 - mean_absolute_error: 0.0865 - val_loss: 0.0247 - val_mean_absolute_error: 0.0881
# Epoch 70/150
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0243 - mean_absolute_error: 0.0866 - val_loss: 0.0246 - val_mean_absolute_error: 0.0869
# Epoch 71/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0248 - val_mean_absolute_error: 0.0882
# Epoch 72/150
# 60000/60000 [==============================] - 7s 109us/sample - loss: 0.0243 - mean_absolute_error: 0.0867 - val_loss: 0.0247 - val_mean_absolute_error: 0.0875
# Epoch 73/150
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0250 - val_mean_absolute_error: 0.0880
# Epoch 74/150
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.0243 - mean_absolute_error: 0.0868 - val_loss: 0.0247 - val_mean_absolute_error: 0.0877
# Epoch 75/150
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0244 - mean_absolute_error: 0.0869 - val_loss: 0.0248 - val_mean_absolute_error: 0.0875
# Epoch 76/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0242 - mean_absolute_error: 0.0865 - val_loss: 0.0246 - val_mean_absolute_error: 0.0870
# Epoch 77/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0243 - mean_absolute_error: 0.0865 - val_loss: 0.0245 - val_mean_absolute_error: 0.0871
# Epoch 78/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0245 - val_mean_absolute_error: 0.0874
# Epoch 79/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0244 - val_mean_absolute_error: 0.0867
# Epoch 80/150
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0239 - mean_absolute_error: 0.0860 - val_loss: 0.0243 - val_mean_absolute_error: 0.0869
# Epoch 81/150
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0246 - val_mean_absolute_error: 0.0877
# Epoch 82/150
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0240 - mean_absolute_error: 0.0861 - val_loss: 0.0248 - val_mean_absolute_error: 0.0872
# Epoch 83/150
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0240 - mean_absolute_error: 0.0862 - val_loss: 0.0245 - val_mean_absolute_error: 0.0875 - loss: 0.0241 - mean_absolute_e
# Epoch 84/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0239 - mean_absolute_error: 0.0859 - val_loss: 0.0243 - val_mean_absolute_error: 0.0867
# Epoch 85/150
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0243 - val_mean_absolute_error: 0.0868
# Epoch 86/150
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0241 - mean_absolute_error: 0.0864 - val_loss: 0.0250 - val_mean_absolute_error: 0.0879
# Epoch 87/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0242 - mean_absolute_error: 0.0864 - val_loss: 0.0242 - val_mean_absolute_error: 0.0866 - ETA: 1s - loss: 0.0243 -
# Epoch 88/150
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.0240 - mean_absolute_error: 0.0861 - val_loss: 0.0243 - val_mean_absolute_error: 0.0867
# Epoch 89/150
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0239 - mean_absolute_error: 0.0857 - val_loss: 0.0249 - val_mean_absolute_error: 0.0882
# Epoch 90/150
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0245 - val_mean_absolute_error: 0.0868
# Epoch 91/150
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.0240 - mean_absolute_error: 0.0859 - val_loss: 0.0243 - val_mean_absolute_error: 0.0867
# Epoch 92/150
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0240 - mean_absolute_error: 0.0859 - val_loss: 0.0244 - val_mean_absolute_error: 0.0869
# Epoch 93/150
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.0246 - mean_absolute_error: 0.0869 - val_loss: 0.0251 - val_mean_absolute_error: 0.0888
# Epoch 94/150
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0250 - mean_absolute_error: 0.0877 - val_loss: 0.0253 - val_mean_absolute_error: 0.0884
# Epoch 95/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0245 - mean_absolute_error: 0.0868 - val_loss: 0.0251 - val_mean_absolute_error: 0.0877
# Epoch 96/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0244 - mean_absolute_error: 0.0867 - val_loss: 0.0251 - val_mean_absolute_error: 0.0878
# Epoch 97/150
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0242 - mean_absolute_error: 0.0863 - val_loss: 0.0245 - val_mean_absolute_error: 0.0865
# Epoch 98/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0242 - mean_absolute_error: 0.0864 - val_loss: 0.0248 - val_mean_absolute_error: 0.0880
# Epoch 99/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0240 - mean_absolute_error: 0.0861 - val_loss: 0.0246 - val_mean_absolute_error: 0.0872
# Epoch 100/150
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0241 - mean_absolute_error: 0.0861 - val_loss: 0.0245 - val_mean_absolute_error: 0.0874
# Epoch 101/150
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.0242 - mean_absolute_error: 0.0863 - val_loss: 0.0251 - val_mean_absolute_error: 0.0882
# Epoch 102/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0252 - mean_absolute_error: 0.0880 - val_loss: 0.0259 - val_mean_absolute_error: 0.0894
# Epoch 103/150
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0254 - mean_absolute_error: 0.0884 - val_loss: 0.0258 - val_mean_absolute_error: 0.0896
# Epoch 104/150
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.0251 - mean_absolute_error: 0.0880 - val_loss: 0.0251 - val_mean_absolute_error: 0.0890
# Epoch 105/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0248 - mean_absolute_error: 0.0874 - val_loss: 0.0250 - val_mean_absolute_error: 0.0882
# Epoch 106/150
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0247 - mean_absolute_error: 0.0872 - val_loss: 0.0250 - val_mean_absolute_error: 0.0885
# Epoch 107/150
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.0246 - mean_absolute_error: 0.0872 - val_loss: 0.0253 - val_mean_absolute_error: 0.0882
# Epoch 108/150
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0244 - mean_absolute_error: 0.0868 - val_loss: 0.0245 - val_mean_absolute_error: 0.0873
# Epoch 109/150
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0241 - mean_absolute_error: 0.0863 - val_loss: 0.0247 - val_mean_absolute_error: 0.0874
# Epoch 110/150
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0241 - mean_absolute_error: 0.0862 - val_loss: 0.0248 - val_mean_absolute_error: 0.0881
# Epoch 111/150
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0241 - mean_absolute_error: 0.0862 - val_loss: 0.0244 - val_mean_absolute_error: 0.0868
# Epoch 112/150
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0242 - val_mean_absolute_error: 0.0864
# Epoch 113/150
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0238 - mean_absolute_error: 0.0857 - val_loss: 0.0243 - val_mean_absolute_error: 0.0863
# Epoch 114/150
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0239 - mean_absolute_error: 0.0859 - val_loss: 0.0243 - val_mean_absolute_error: 0.0867
# Epoch 115/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0245 - val_mean_absolute_error: 0.0874
# Epoch 116/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0238 - mean_absolute_error: 0.0856 - val_loss: 0.0243 - val_mean_absolute_error: 0.0867
# Epoch 117/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0242 - val_mean_absolute_error: 0.0864
# Epoch 118/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0238 - mean_absolute_error: 0.0857 - val_loss: 0.0248 - val_mean_absolute_error: 0.0880
# Epoch 119/150
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.0240 - mean_absolute_error: 0.0860 - val_loss: 0.0242 - val_mean_absolute_error: 0.0860
# Epoch 120/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0238 - mean_absolute_error: 0.0856 - val_loss: 0.0241 - val_mean_absolute_error: 0.0864
# Epoch 121/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0238 - mean_absolute_error: 0.0855 - val_loss: 0.0243 - val_mean_absolute_error: 0.0865
# Epoch 122/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0240 - mean_absolute_error: 0.0859 - val_loss: 0.0241 - val_mean_absolute_error: 0.0860
# Epoch 123/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0240 - val_mean_absolute_error: 0.0860
# Epoch 124/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0238 - mean_absolute_error: 0.0855 - val_loss: 0.0240 - val_mean_absolute_error: 0.0860
# Epoch 125/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0854 - val_loss: 0.0242 - val_mean_absolute_error: 0.0866
# Epoch 126/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0242 - val_mean_absolute_error: 0.0864
# Epoch 127/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0244 - val_mean_absolute_error: 0.0870
# Epoch 128/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0237 - mean_absolute_error: 0.0852 - val_loss: 0.0240 - val_mean_absolute_error: 0.0858
# Epoch 129/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0238 - mean_absolute_error: 0.0855 - val_loss: 0.0243 - val_mean_absolute_error: 0.0871
# Epoch 130/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0852 - val_loss: 0.0245 - val_mean_absolute_error: 0.0867
# Epoch 131/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0239 - val_mean_absolute_error: 0.0855
# Epoch 132/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0236 - mean_absolute_error: 0.0851 - val_loss: 0.0240 - val_mean_absolute_error: 0.0857
# Epoch 133/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0243 - val_mean_absolute_error: 0.0858
# Epoch 134/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0238 - mean_absolute_error: 0.0855 - val_loss: 0.0243 - val_mean_absolute_error: 0.0863
# Epoch 135/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0236 - mean_absolute_error: 0.0851 - val_loss: 0.0239 - val_mean_absolute_error: 0.0858
# Epoch 136/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0236 - mean_absolute_error: 0.0851 - val_loss: 0.0248 - val_mean_absolute_error: 0.0882
# Epoch 137/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0237 - mean_absolute_error: 0.0852 - val_loss: 0.0241 - val_mean_absolute_error: 0.0860
# Epoch 138/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0244 - val_mean_absolute_error: 0.0872
# Epoch 139/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0240 - mean_absolute_error: 0.0860 - val_loss: 0.0243 - val_mean_absolute_error: 0.0866
# Epoch 140/150
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0236 - mean_absolute_error: 0.0851 - val_loss: 0.0240 - val_mean_absolute_error: 0.0855
# Epoch 141/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0235 - mean_absolute_error: 0.0849 - val_loss: 0.0242 - val_mean_absolute_error: 0.0864
# Epoch 142/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0237 - mean_absolute_error: 0.0852 - val_loss: 0.0243 - val_mean_absolute_error: 0.0865
# Epoch 143/150
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0238 - mean_absolute_error: 0.0854 - val_loss: 0.0244 - val_mean_absolute_error: 0.0869
# Epoch 144/150
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0239 - mean_absolute_error: 0.0857 - val_loss: 0.0243 - val_mean_absolute_error: 0.0862
# Epoch 145/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0240 - mean_absolute_error: 0.0858 - val_loss: 0.0243 - val_mean_absolute_error: 0.0865
# Epoch 146/150
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.0237 - mean_absolute_error: 0.0853 - val_loss: 0.0241 - val_mean_absolute_error: 0.0863
# Epoch 147/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0239 - mean_absolute_error: 0.0858 - val_loss: 0.0242 - val_mean_absolute_error: 0.0865
# Epoch 148/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0236 - mean_absolute_error: 0.0851 - val_loss: 0.0240 - val_mean_absolute_error: 0.0857
# Epoch 149/150
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0236 - mean_absolute_error: 0.0852 - val_loss: 0.0239 - val_mean_absolute_error: 0.0856
# Epoch 150/150
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.0235 - mean_absolute_error: 0.0850 - val_loss: 0.0240 - val_mean_absolute_error: 0.0858

# %%
### 視覺化 - 資料還原與還原誤差

def reconstructed_img(idx):
    # Prepare image to be reconstructed
    x = x_train[idx:idx+1]
    y = y_train0[idx]
    x_hat = autoencoder.predict(x)

    # Reshape for plotting  
    x = x.reshape(28, 28)
    x_hat = x_hat.reshape(28, 28)
    rec_error = np.abs(x-x_hat)

    # Prepare a canvas for plotting
    plt.figure(figsize=(12, 9))
    ax1 = plt.subplot2grid((2,3),(0,0))
    ax2 = plt.subplot2grid((2,3),(0,1))
    ax3 = plt.subplot2grid((2,3),(0,2))
    ax4 = plt.subplot2grid((2,3),(1,0), colspan=3)

    # Plot raw image
    ax1.imshow(x, 'Greys')
    ax1.set_title(f'Number: {y}')

    # Plot reconstructed image
    ax2.imshow(x_hat, 'Greys')
    ax2.set_title('Reconstructed Image')

    # Plot reconstruction error
    ax3.imshow(rec_error, 'Greys')
    ax3.set_title('Reconstructed Error')
    ax4.hist(rec_error.flatten(), bins=20, rwidth=0.5)
    ax4.set_title('Histogram of Reconstructed Error')
    
# Plot
interact(reconstructed_img, idx=IntSlider(min=0, max=x_train.shape[0], step=1, value=3));
# Out:
# interactive(children=(IntSlider(value=3, description='idx', max=60000), Output()), _dom_classes=('widget-inter…

# %%
### 將 Encoder 和 Decoder 分別定義出來。

Encoder = Model(x, z)
Encoder.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               100480
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_38 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 108,866
# Trainable params: 108,866
# Non-trainable params: 0
# _________________________________________________________________

# %%
### z要改為input的形式

z_input = Input(shape=(2,))
Decoder = Model(z_input, dec_1(dec_2(dec_3(z_input))))

Decoder.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 2)]               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_41 (Dense)             (None, 784)               101136
# =================================================================
# Total params: 109,648
# Trainable params: 109,648
# Non-trainable params: 0
# _________________________________________________________________

# %%
### 將encoder視覺化

idx = np.random.randint(x_train.shape[0])
print(f"第 {idx} 圖的 latent 表示為 {Encoder.predict(x_train[idx: idx+1]).squeeze()}")
# Out:
# 第 23491 圖的 latent 表示為 [0.12213983 0.00194692]

# %%
indices = np.random.randint(x_train.shape[0], size=3000)

# %%
latents = Encoder.predict(x_train[indices])
plt.scatter(latents[:, 0], latents[:, 1], c=y_train0[indices], cmap="tab10")
plt.colorbar()
plt.show()

# %%
### 視覺化 Decoder

n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
grid_x = np.linspace(0.05, 0.95, n)
grid_y = np.linspace(0.05, 0.95, n)

# %%
for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = Decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[(n-i-1) * digit_size: (n - i) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
XX, YY = np.meshgrid(grid_x, grid_y)
plt.scatter(XX, YY)

plt.subplot(1, 2, 2)
plt.imshow(figure, cmap='Greys')
plt.axis('off')
plt.show()

# %% [markdown]
# Variational Autoencoder

# %%
enc_1 = Dense(100, activation='sigmoid')
# enc_2 = Dense(2, activation='sigmoid')

enc_mean = Dense(2)
enc_log_var = Dense(2)

dec_2 = Dense(100, activation='sigmoid')
dec_2 = Dense(400, activation='sigmoid')
dec_1 = Dense(784, activation='sigmoid')

# %%
x = Input(shape=(784,))
enc_x = enc_1(x)

z_mean = enc_mean(enc_x)
z_log_var = enc_log_var(enc_x)

# %%
def sampling(args):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    # by default, random_normal has mean = 0 and std = 1.0
    epsilon = K.random_normal(shape=(batch, dim))
    return z_mean + K.exp(0.5 * z_log_var) * epsilon

# %%
z = Lambda(sampling, output_shape=(2,))([z_mean, z_log_var])

# %%
# Define Decoder part of VAE
z_input = Input(shape=(2,))
x_hat = dec_1(dec_2(z_input))

# %%
x_hat = dec_1(dec_2(z))

VAE = Model(x, x_hat)
VAE.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 100)          78500       input_15[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 2)            202         dense_42[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 2)            202         dense_42[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 2)            0           dense_43[0][0]
#                                                                  dense_44[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 400)          1200        lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 784)          314384      dense_46[1][0]
# ==================================================================================================
# Total params: 394,488
# Trainable params: 394,488
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## Loss 函數的建立
reconstruction_loss = 784 * losses.mean_squared_error(x, x_hat)

kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5

vae_loss = K.mean(reconstruction_loss + kl_loss)

VAE.add_loss(vae_loss)

# %%
## 訓練 VAE
VAE.compile(optimizer=Adam())
# Out:
# WARNING:tensorflow:Output dense_47 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_47.

# %%
VAE.fit(x_train, 
        batch_size=256, 
        epochs=20)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 56.5705
# Epoch 2/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 40.1948
# Epoch 3/20
# 60000/60000 [==============================] - 5s 83us/sample - loss: 39.3822
# Epoch 4/20
# 60000/60000 [==============================] - 5s 84us/sample - loss: 39.1546
# Epoch 5/20
# 60000/60000 [==============================] - 6s 97us/sample - loss: 39.0074
# Epoch 6/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 38.8675
# Epoch 7/20
# 60000/60000 [==============================] - 5s 88us/sample - loss: 38.7029
# Epoch 8/20
# 60000/60000 [==============================] - 6s 100us/sample - loss: 38.3041
# Epoch 9/20
# 60000/60000 [==============================] - 5s 88us/sample - loss: 37.4552
# Epoch 10/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 36.4422
# Epoch 11/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 35.8323s -
# Epoch 12/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 35.3917
# Epoch 13/20
# 60000/60000 [==============================] - 4s 70us/sample - loss: 34.9816
# Epoch 14/20
# 60000/60000 [==============================] - 4s 67us/sample - loss: 34.5297
# Epoch 15/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 34.1240
# Epoch 16/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 33.7171
# Epoch 17/20
# 60000/60000 [==============================] - 5s 85us/sample - loss: 33.4169
# Epoch 18/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 33.1091
# Epoch 19/20
# 60000/60000 [==============================] - 4s 69us/sample - loss: 32.8556
# Epoch 20/20
# 60000/60000 [==============================] - 4s 68us/sample - loss: 32.6231

# %%
### 視覺化

VAE_Encoder = Model(x, z_mean)

VAE_Encoder.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 784)]             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 100)               78500
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 78,702
# Trainable params: 78,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
VAE_Decoder = Model(z_input, dec_1(dec_2(z_input)))

VAE_Decoder.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 2)]               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 400)               1200
# _________________________________________________________________
# dense_47 (Dense)             (None, 784)               314384
# =================================================================
# Total params: 315,584
# Trainable params: 315,584
# Non-trainable params: 0
# _________________________________________________________________

# %%
### encoder 視覺化

idx = np.random.randint(x_train.shape[0])
print(f"第 {idx} 圖的 latent 表示為 {VAE_Encoder.predict(x_train[idx: idx+1]).squeeze()}")
# Out:
# 第 53425 圖的 latent 表示為 [0.0256971 0.0658534]

# %%
VAE_latents = VAE_Encoder.predict(x_train[indices])

# %%
plt.figure(figsize=(10, 8))
plt.scatter(VAE_latents[:, 0], VAE_latents[:, 1], c=y_train0[indices], cmap='tab20')
plt.colorbar()
plt.show()

# %%
### decoder 視覺化

def normalized(x):
    x -= x.min()
    x /= x.max()
    return x

# %%
grid_x_vae = np.linspace(-4+0.05, 4-0.05, n)
grid_y_vae = np.linspace(-4+0.05, 4-0.05, n)
VAE_figure = np.zeros((digit_size * n, digit_size * n))
for i, yi in enumerate(grid_x_vae):
    for j, xi in enumerate(grid_y_vae):
        z_sample = np.array([[xi, yi]])
        x_decoded = VAE_Decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        VAE_figure[(n-i-1) * digit_size: (n - i) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = normalized(digit)

# %%
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
XXX, YYY = np.meshgrid(grid_x_vae, grid_y_vae)
plt.scatter(XXX, YYY)

plt.subplot(1, 2, 2)
plt.imshow(figure, cmap='Greys')
plt.axis('off')
plt.show()

# %%
### 與 Autoencoder 進行視覺化比較

plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.scatter(VAE_latents[:, 0], VAE_latents[:, 1], c=y_train0[indices], cmap='tab10')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.scatter(latents[:, 0], latents[:, 1], c=y_train0[indices], cmap="tab10")
plt.colorbar()
plt.show()

# %%
###  動態比較

idx_1, idx_2 = np.random.randint(x_train.shape[0], size=2)

def inBetween(t):
    data_0 = x_train[idx_1].reshape(28, 28)
    data_1 = x_train[idx_2].reshape(28, 28)
    data_t = (1-t)*data_0 + t*data_1
    
    mu_0 = VAE_Encoder.predict(x_train[idx_1:idx_1+1]).squeeze()
    mu_1 = VAE_Encoder.predict(x_train[idx_2:idx_2+1]).squeeze()
    mu_t = (1-t)*mu_0 + t*mu_1

    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(2, 1, 2)
    ax1.scatter(mu_0[0], mu_0[1])
    ax1.scatter(mu_1[0], mu_1[1])
    ax1.scatter(mu_t[0], mu_t[1])

    ax2 = plt.subplot(2, 3, 1)
    ax2.imshow(data_0, cmap='Greys')
    ax2.set_title('t=0')

    ax3 = plt.subplot(2, 3, 2)
    ax3.imshow(data_t, cmap='Greys')
    ax3.set_title(f't={t}')

    ax4 = plt.subplot(2, 3, 3)
    ax4.imshow(data_1, cmap='Greys')
    ax4.set_title('t=1')

# %%
interact(inBetween, t=FloatSlider(value=0, 
                                  min=0, 
                                  max=1.0,
                                  step=0.02,))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.02), Output()), _dom_classes=('w…
# <function __main__.inBetween(t)>
